# %% [markdown]
# # Theorem 3: Logarithmic Depth Scaling
#
# Verifies L_min = k_c · log(ξ_data / ξ_target). The log relationship is decisive.

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import matplotlib.pyplot as plt
import torch

from src.utils.seed_registry import SeedRegistry
from src.utils.device_manager import DeviceManager

SeedRegistry.get_instance().set_master_seed(42)
device = DeviceManager.get_instance().get_device()
print(f'Device: {device}')

# %% [markdown]
# ## Theoretical vs Empirical Depth Scaling

# %%
from src.proofs.theorem3_depth_scaling import lmin_theoretical, verify_logarithmic_scaling, run_all_verifications

results = run_all_verifications()
print("Theorem 3 verification:", results)

# Reproduce H2 main figure
xi_vals = np.linspace(2, 200, 100)
for k_c in [5, 10, 20]:
    l_min = lmin_theoretical(xi_vals, k_c=k_c)
    plt.loglog(xi_vals, l_min, label=f"k_c={k_c}")

plt.scatter([5, 15, 50, 100, 200],
            lmin_theoretical(np.array([5,15,50,100,200]), k_c=10),
            color="red", zorder=5, label="Hier-1..5 (paper)")
plt.xlabel("ξ_data (log scale)"); plt.ylabel("L_min (log scale)")
plt.title("Theorem 3: Logarithmic Depth Scaling"); plt.legend(); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()
